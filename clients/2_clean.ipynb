# %%
# %run ./1_raw
# Out:
# # Завантаження даних
# clients shape: (1132367, 5)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %run ../dishes/3_gold
# Out:
# # Завантаження даних
# dishes shape: (231637, 12)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Очищення та форматування типів даних

# %%
clients_silver = clients.copy()

clients_silver['date'] = pd.to_datetime(clients_silver['date'], errors='coerce')
clients_silver['rating'] = pd.to_numeric(clients_silver['rating'], errors='coerce').astype('Int64')

null_reviews_before = clients_silver['review'].isna().sum()
clients_silver['review'] = clients_silver['review'].fillna("")

# %% [markdown]
# # Видалення оцінок з рейтином 0
# рейтинг (1-5)

# %%
initial_rows = clients_silver.shape[0]

clients_silver = clients_silver[clients_silver['rating'] > 0]

print(f"Number of removed reviews with 0 rating: {clients_silver.shape[0]}")
print(f"Were removed: {initial_rows - clients_silver.shape[0]} rows")
# Out:
# Number of removed reviews with 0 rating: 1071520
# Were removed: 60847 rows

# %% [markdown]
# # Видалення відгуків без страв

# %%
initial_rows = clients_silver.shape[0]

valid_recipe_ids = dishes_gold['id'].unique()

clients_silver = clients_silver[clients_silver['recipe_id'].isin(valid_recipe_ids)]

print(f"Final number of reviews: {clients_silver.shape[0]}")
# Out:
# Final number of reviews: 1066869
